# %%
# This is Main function.
# Extracting streaming data from Twitter, pre-processing, and loading into MySQL
import configuration # Import api/access_token keys from configuration.py
import settings # Import related setting constants from settings.py 

import re
import tweepy
import mysql.connector
import pandas as pd
from textblob import TextBlob
# Streaming With Tweepy 
# http://docs.tweepy.org/en/v3.4.0/streaming_how_to.html#streaming-with-tweepy

# %%
# Override tweepy.StreamListener to add logic to on_status
class MyStreamListener(tweepy.StreamListener):
    '''
    Tweets are known as “status updates”. So the Status class in tweepy has properties describing the tweet.
    https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object.html
    '''
    
    def on_status(self, status):
        '''
        Extract info from tweets
        '''
        
        if status.retweeted:
            # Avoid retweeted info, and only original tweets will be received
            return True
        # Extract attributes from each tweet
        id_str = status.id_str
        created_at = status.created_at
        text = deEmojify(status.text)    # Pre-processing the text  
        sentiment = TextBlob(text).sentiment
        polarity = sentiment.polarity
        subjectivity = sentiment.subjectivity
        
        user_created_at = status.user.created_at
        user_location = deEmojify(status.user.location)
        user_description = deEmojify(status.user.description)
        user_followers_count =status.user.followers_count
        longitude = None
        latitude = None
        if status.coordinates:
            longitude = status.coordinates['coordinates'][0]
            latitude = status.coordinates['coordinates'][1]
            
        retweet_count = status.retweet_count
        favorite_count = status.favorite_count
        
        print(status.text)
        print("Long: {}, Lati: {}".format(longitude, latitude))
        
        # Store all data in MySQL
        if mydb.is_connected():
            mycursor = mydb.cursor()
            sql = "INSERT INTO {} (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)".format(settings.TABLE_NAME)
            val = (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, \
                user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count)
            mycursor.execute(sql, val)
            mydb.commit()
            mycursor.close()
    
    
    def on_error(self, status_code):
        '''
        Since Twitter API has rate limits, stop srcraping data as it exceed to the thresold.
        '''
        if status_code == 420:
            # return False to disconnect the stream
            return False

# %%
def clean_tweet(self, tweet): 
    ''' 
    Use sumple regex statemnents to clean tweet text by removing links and special characters
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) \
                                |(\w+:\/\/\S+)", " ", tweet).split()) 
def deEmojify(text):
    '''
    Strip all non-ASCII characters to remove emoji characters
    '''
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
mydb = mysql.connector.connect(
    host="localhost",
    user="jetemi1",
    password="jetemi1@0025",
    database="twitterdb",
    charset = 'utf8'
)
if mydb.is_connected():
    '''
    Check if this table exits. If not, then create a new one.
    '''
    mycursor = mydb.cursor()
    mycursor.execute("""
        SELECT COUNT(*)
        FROM information_schema.tables
        WHERE table_name = '{0}'
        """.format(settings.TABLE_NAME))
    if mycursor.fetchone()[0] != 1:
        mycursor.execute("CREATE TABLE {} ({})".format(settings.TABLE_NAME, settings.TABLE_ATTRIBUTES))
    
        mydb.commit()
    mycursor.close()

# %%
auth  = tweepy.OAuthHandler(configuration.API_KEY, configuration.API_SECRET_KEY)
auth.set_access_token(configuration.ACCESS_TOKEN, configuration.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
myStream.filter(languages=["en"], track = settings.TRACK_WORDS)
# Close the MySQL connection as it finished
# However, this won't be reached as the stream listener won't stop automatically
# Press STOP button to finish the process.
mydb.close()
# Out:
# l not be judged b…
# Long: None, Lati: None
# RT @RepAishaGomez: The war on drugs has been a disaster.
#
# Fueled by misinformation and rooted in racism it has made us less safe and crimi…
# Long: None, Lati: None
# RT @VancouverJohn1: @RobynUrback The communications are a disaster. Canada is one big amateur shambles
# Long: None, Lati: None
# RT @mathewmantony: I promise you Mr. @narendramodi , there will be a day where the people of this Nation will not be judged by the color of…
# Long: None, Lati: None
# RT @gargsahil58: Thank you for supporting this cause
#
# #UPSCExtraAttempt2021 #Age_Relaxation
# @PMOIndia @DoPTGoI @narendramodi @DrJitendraS…
# Long: None, Lati: None
# RT @zewdi15: If US has sent millions in additional funds 2Tigray 2 assist in responding 2 z humanitarian crisis &amp; has deployed a US Agency…
# Long: None, Lati: None
# RT @nandtara: In January, ⁦@PMOIndia⁩ declared India had “saved humanity from a big disaster by containing corona effectively.” Four months…
# Long: None, Lati: None
# LYING FLED CRUZ left the country during the worst TX disaster to date.
# 26 people dead. 300+ treated for carbon mono… https://t.co/nWsiBaedmG
# Long: None, Lati: None
# RT @Marvel0usJesus: “For I know the plans I have for you," says the LORD. "They are plans for good and not for disaster, to give you a futu…
# Long: None, Lati: None
# @6abc Still cant report on the disaster that is harris biden can you..
# Long: None, Lati: None
# @JurisDumbass Also, aren’t the first people to get the vaccines going to start losing their immunity soon?
# Covid d… https://t.co/8GuLVgz7Zm
# Long: None, Lati: None
# @JudahWorldChamp @danaparish @CDCgov “Once disintegration &amp; destruction becomes the primary source of profit, catab… https://t.co/cJkOdgoA0T
# Long: None, Lati: None
# RT @Rakesh_6342: #UPSCExtraAttempt2021
# Thank you sir for raising our justified demand....
#
# @narendramodi
#
# @PMOIndia
#
# @AmitShah
#
# @DrJitend…
# Long: None, Lati: None
# RT @LTCEyalDror: #IsraelUnderAttack
# How poor are the #HamasTerrorists? How many lies they can tell? Not ashamed to use the disaster of the…
# Long: None, Lati: None
# RT @Poonam89625917: Thank you sir, for supporting us.
# Hope we get an attempt this year and get a last chance to prove ourselves.
# Just one l…
# Long: None, Lati: None
# Whatever it is but feku is still a disaster.
# Long: None, Lati: None
# This is such an adorable name for a potentially deadly natural disaster 🦎🌀
# Long: None, Lati: None
# @SimplexCC Finally got my BNBSC after 70hrs... Please Simplex fix your service, tons of new investors rely on your… https://t.co/YTF2BvrzEi
# Long: None, Lati: None
# @SIoaneRanger Sorry I shouldn’t laugh but his american wife hasn’t done a very good job of educating him has she. H… https://t.co/S33K9N66FD
# Long: None, Lati: None
# @VicKingArt Aside from the lockdown? Well, a decent barber who hates the Justin Bieber soycut.
#
# But I guess some wo… https://t.co/W315UoeA5Y
# Long: None, Lati: None
# RT @jascrawfovd: I didn't know that I was starving till I
# tasted you, don't need no butterflies
# when you give me the whole damn
# zoo by t…
# Long: None, Lati: None
# RT @BylineTimes: COVID Variants and a Third Wave: Scientists Warn Government Is ‘Sleepwalking into Disaster’
#
# https://t.co/Xfx57FaDuz
# Long: None, Lati: None
# RT @PankajC47069041: Covid-19 pandemic ruined our last attempt. Sir, Please! Show compassion to us.
# #UPSCExtraAttempt2021
# #Age_Relaxation…
# Long: None, Lati: None
# RT @Abhina_Prakash: Criticizing present day vaccination policy shouldn’t mean presenting a rosy picture of past failures. Pulse polio progr…
# Long: None, Lati: None
# RT @BoxOfficeIND_: #Radhe turning out to be a huge Disaster for Zee. Reports overwhelmingly negative and revenues Below-par even after bein…
# Long: None, Lati: None
# Greyhound Canada closure will be a ‘disaster’ for rural communities, experts say https://t.co/Od4dWflBKK
# Long: None, Lati: None
# RT @Ravidabra07: #महा_मूर्ख_दिवस
# I promise you Mr.@narendramodi , there will be a day where the people of this Nation will not be judged b…
# Long: None, Lati: None
# RT @AnnieWellsMSP: It shouldn’t have come to this, but many of our young people, and teachers, are incredibly stressed and anxious due to t…
# Long: None, Lati: None
# @davidkerr1970 Flagshagger's bid to join the 20ft-high club ends in disaster.
# Long: None, Lati: None
# RT @SinghShaktiBJP: The way the whole country is upset at the time of this disaster, similarly the student preparing for #UPSC is also upse…
# Long: None, Lati: None
# RT @fekubawa: Kumbh blast in Uttarakhand:
# 12 April:
# Confirmed cases: 1,10,000
# Active cases: 7,846
#
# 14 May:
# Confirmed cases: 2,71,810
# Active…
# Long: None, Lati: None
# @GillPlusFive It's true. You were the one who got off your bum and did something about it and, because of you, we a… https://t.co/1dw4z1UhfW
# Long: None, Lati: None
# RT @BadGyallRiRi: Idk if ppl realize how important it is to not get comfortable in your relationship. It’s a recipe for disaster. Pay atten…
# Long: None, Lati: None
# @IMS @jdouglas4 @JeffreyToddSch1 @CDCgov Seriously, @jdouglas4, I can live with the mask requirement. I plan to hav… https://t.co/WVVhVs4lNK
# Long: None, Lati: None
# RT @fekubawa: Kumbh blast in Uttarakhand:
# 12 April:
# Confirmed cases: 1,10,000
# Active cases: 7,846
#
# 14 May:
# Confirmed cases: 2,71,810
# Active…
# Long: None, Lati: None
# @Thembisile_Q It a disaster ended in tears https://t.co/3JoGpaugVN
# Long: None, Lati: None
# @gailkimITSME it depends on the brand. Samsung hardly gives me any problems. I used another brand I won't name once… https://t.co/u4rjuYJqAx
# Long: None, Lati: None
# RT @tcsavunma: 1⃣The attention of the Turkish TCG GAZİANTEP personnel off Libya prevented a huge disaster in the Mediterranean Sea. 97 irre…
# Long: None, Lati: None
# RT @PhotonSush21: After Sadak thoo
# Gadhe became the disaster...
# #राधे_फिल्म_का_बहिष्कार_करो #BoycottRadhe
# Long: None, Lati: None
# Hear from experts on key High Availability and Disaster Recovery technologies such as: Real Application Clusters (R… https://t.co/btyrqO8TN3
# Long: None, Lati: None
# RT @JayCuse96: @MarkWeinerDC @chrsbakr OMG.... a disgraced President's hand picked candidate replaces @RepLizCheney.  Stefanik calls Biden…
# Long: None, Lati: None
# @janmaxwell @Redistrict It’s poison in the cities and suburbs too. Trump supporters statewide have gotten smashed i… https://t.co/P5sEI4eIDe
# Long: None, Lati: None
# My sweet strawberry girls! Please ignore the disaster of our hotel homelessness behind them - thanks… https://t.co/YQUeDjxBqB
# Long: None, Lati: None
# A bill that prohibits schools "from requiring the teachers, other staff, or students of a school to wear a face mas… https://t.co/xamNYPfLJy
# Long: None, Lati: None
# RT @fekubawa: Kumbh blast in Uttarakhand:
# 12 April:
# Confirmed cases: 1,10,000
# Active cases: 7,846
#
# 14 May:
# Confirmed cases: 2,71,810
# Active…
# Long: None, Lati: None
# RT @leticiakawano: @CedricMas You don't wanna know the harm the HCQ discourse has caused in Brazil (also promoted by 🇧🇷 President).
#
# People…
# Long: None, Lati: None
# RT @Jonathan_Witt: It would appear as if we will never exit this ‘State of Disaster’ which hands the ANC Government unconstitutional contro…
# Long: None, Lati: None
# RT @MiamiHerald: NEW: ‘An impending disaster.’ Worsening algae bloom on Lake Okeechobee threatens coasts again https://t.co/pvwnrYJo5I
# Long: None, Lati: None
# RT @fekubawa: Kumbh blast in Uttarakhand:
# 12 April:
# Confirmed cases: 1,10,000
# Active cases: 7,846
#
# 14 May:
# Confirmed cases: 2,71,810
# Active…
# Long: None, Lati: None
# Thanks sir for supporting our cause 🙏🙏
# Long: None, Lati: None
# RT @RioGrandeFndn: Great article by @JusticeTristan of @FDRLST describes New Mexico's energy issues &amp; perspective regarding the East Coast…
# Long: None, Lati: None
# If I can’t be comfortable in my relationship, then I don’t want it. I love comfort and a comfortable life 💯.
# Long: None, Lati: None
# Root Causes of Forced Migration: Climate Change, Food Production, and Environmental Disaster (Part 2) https://t.co/zMnrZewpoD
# Long: None, Lati: None
# Greyhound Canada closure will be a ‘disaster’ for rural communities, experts say. "Now how will I get back home to… https://t.co/DBJKVi9boV
# Long: None, Lati: None
# @CalmAfterTheTim i know 😭 it's a disaster
# Long: None, Lati: None
# ADEM congratulates Duty Officer Wanda Cook on 10 years of service.  Wanda says she loves the people here and the re… https://t.co/wluyB9Z3Dg
# Long: None, Lati: None
# Right next to a traffic post &amp; stones throw from Pragati Maidan PS. No regards for #Covid protocols &amp; disaster mana… https://t.co/kMvVYPpj0N
# Long: None, Lati: None
# Want to read. I have a lot of faith in humanity, especially for a prepper...
# Long: None, Lati: None
# Tin Ko Ko, Secretary of NLD office from Mandalay faced additional charges under violating Article 25 of the Natural… https://t.co/A6YgAk3QVI
# Long: None, Lati: None
# Example of people who set themself up for disaster for not listening.
# 1. First you tell them an event happened and… https://t.co/S7IygGR1B4
# Long: None, Lati: None
# Remodeling can make your disaster into something beautiful. Place your material order online and we'll have it read… https://t.co/aM4rksD1PY
# Long: None, Lati: None
# Thank you so much for supporting our cause
#
# #UPSCExtraAttempt2021
# #Age_Relaxation
# @narendramodi
# @PMOIndia… https://t.co/ylv2iGZbLp
# Long: None, Lati: None
# lol you think it’s a curse to be black cos you are a c**n that doesn’t know his roots. that’s not on other black pe… https://t.co/69jJLf6CaB
# Long: None, Lati: None
# RT @Marvel0usJesus: “For I know the plans I have for you," says the LORD. "They are plans for good and not for disaster, to give you a futu…
# Long: None, Lati: None
# "Plot holes" and their consequences have been a disaster for film criticism.
# Long: None, Lati: None
# Death Lights
# #blackoutpoetry by Jessica McHugh
#
# I am a disaster
# drawn to the highways
# to re-form
# the livestock call… https://t.co/gdTSfQj4Up
# Long: None, Lati: None
# RT @Rakesh_6342: Thank you so much for supporting our cause
#
# #UPSCExtraAttempt2021
# #Age_Relaxation
# @narendramodi
# @PMOIndia
# @AmitShah
# @DrJ…
# Long: None, Lati: None
# RT @AnthonyDaBruzzi: “We want to make sure that there are resources there that if a natural disaster or another national pandemic or someth…
# Long: None, Lati: None
# RT @fekubawa: Kumbh blast in Uttarakhand:
# 12 April:
# Confirmed cases: 1,10,000
# Active cases: 7,846
#
# 14 May:
# Confirmed cases: 2,71,810
# Active…
# Long: None, Lati: None
# RT @jyotiyadaav: At a time when there is a tussle between states over oxygen supply at the national level, Bihar saw its districts coming t…
# Long: None, Lati: None
# @YahooNews Hilarious that the garbage dump Fake News is still milking this.... anything to avoid Disaster JOE here on Leftist Mass Media.
# Long: None, Lati: None
# RT @sisir_sniper: Blockbuster Or disaster
#
# With mahesh babu always.....
# #SarkaruVaariPaata
# @urstrulyMahesh
# #LoveYouSUPERSTAR
# Long: None, Lati: None
# @Chunkyferryman @Cantii5 @GaelicRoadSign @Missgabillard Gloom and doom eh? If every country in EU had your attitude… https://t.co/q335a70CRe
# Long: None, Lati: None
# @NewsAsset You should pin it and I believe in their vision but it has been a disaster for those I have referred and… https://t.co/N1awjX8KfU
# Long: None, Lati: None
# I can't just go out of this tunnel, Sir! Please don't cover me up! I just don't want the #SodorFlood to ruin my lov… https://t.co/RXlu6eLMmx
# Long: None, Lati: None
# RT @Rakesh_6342: Thank you so much for supporting our cause
#
# #UPSCExtraAttempt2021
# #Age_Relaxation
# @narendramodi
# @PMOIndia
# @AmitShah
# @DrJ…
# Long: None, Lati: None
# RT @PerspicaciousXY: I’m old enough to remember when the market would sell off 200 points and the media would scream about Trump’s reckless…
# Long: None, Lati: None
# RT @fekubawa: Kumbh blast in Uttarakhand:
# 12 April:
# Confirmed cases: 1,10,000
# Active cases: 7,846
#
# 14 May:
# Confirmed cases: 2,71,810
# Active…
# Long: None, Lati: None
# Signed copies of the brilliant #LeanFallStand @jon_mcgregor  instore and at https://t.co/iRnjeVMvFx
#
# Disaster in An… https://t.co/Cuos7D7Vyr
# Long: None, Lati: None
# RT @ikkmurugan: The government sources already clarified immediately after PM cares was setup as to why this fund was set up &amp; why the Nati…
# Long: None, Lati: None
# RT @RWeldemariam: If the US has sent millions in additional funds 2Tigray 2 assist in responding 2 z humanitarian crisis &amp; has deployed a U…
# Long: None, Lati: None
# This should be obvious, but the solution to this giant pipeline disaster is not more pipelines.… https://t.co/ZHa5dAjtt3
# Long: None, Lati: None
# do you mean the rebels who are TEMPORARILY occupying the legal territories of the republic of china?
# https://t.co/t0sgXAYoHQ
# Long: None, Lati: None
# RT @MadhilSaleem: OMG. This is disaster. Impact assessment for a land reclaimed airport in location has definitely been done wrong.
#
# What…
# Long: None, Lati: None
# Triumph and disaster, treat those two impostors just the same.
#
# Nah, screw that.
# Long: None, Lati: None
# So vax &gt;60% of the pop isnt stopping #COVID19India - going to lockdown indefinitely? Doesn't even include the unvax… https://t.co/oG7Mi4OjKe
# Long: None, Lati: None
# RT @ifidiefirstband: IF I DIE FIRST X SEEYOUSPACECOWBOY - A SURE DISASTER (SPLIT EP) OUT NOW EVERYWHERE
#
# https://t.co/KFhKarbif5 https://t…
# Long: None, Lati: None
# @TedPavlic @danielmangrum @daveamp I’ve done it as sending a screen shot of the completion screen for participation… https://t.co/2ee2LD5zhp
# Long: None, Lati: None
# @merissahamilton @maricopacounty @jacksellers Jack Sellers is a MAJOR part of the problem. He clearly has ZERO inte… https://t.co/mBKLbAov8B
# Long: None, Lati: None
# RT @fekubawa: Kumbh blast in Uttarakhand:
# 12 April:
# Confirmed cases: 1,10,000
# Active cases: 7,846
#
# 14 May:
# Confirmed cases: 2,71,810
# Active…
# Long: None, Lati: None
# This is something that nobody actually cares about, but the Iowa athletic department found a way to turn it into a… https://t.co/RN3h9jZBZ3
# Long: None, Lati: None
# Statements such as this by @DrAhmadLawan only go to confirm that the man is NOT only an underling, but also an appe… https://t.co/zkRiJ9atOe
# Long: None, Lati: None
# RT @Poonam89625917: Thank you sir, for supporting us.
# Hope we get an attempt this year and get a last chance to prove ourselves.
# Just one l…
# Long: None, Lati: None
# Google's balloon travel in the stratosphere to deliver internet and connectivity to people in remote and disaster a… https://t.co/JT6YIG9mYj
# Long: None, Lati: None
# RT @gadyepstein: I wrote this week about Xi Jinping's favorite winter sport, ice hockey. The China men's team is going to be crushed at nex…
# Long: None, Lati: None
# (continuing)
# 20. The Offspring
# 21. Tin Man
# 22. The Best of Both Worlds
# 23. The Best of Both Worlds, II
# 24. Reunion… https://t.co/1AYQRyiLmG
# Long: None, Lati: None
# RT @Rakesh_6342: Thank you so much for supporting our cause
#
# #UPSCExtraAttempt2021
# #Age_Relaxation
# @narendramodi
# @PMOIndia
# @AmitShah
# @DrJ…
# Long: None, Lati: None
# @tolkens774 @ScotTories The SNP are responsible for education in Scotland and unless you have a child sitting exams… https://t.co/yXLQvay4zQ
# Long: None, Lati: None
# Hey @thedailybeast! Has @mattklewis ever been right? His Fox News schtick of cantilevering disaster (for the Dems)… https://t.co/Oh4wROgUa0
# Long: None, Lati: None
# RT @BeyondType1: 🚨It's almost hurricane season, and the time to pack your diabetes emergency kit is NOW.
#
# What to pack:
# 💉Diabetes kit with…
# Long: None, Lati: None
# RT @Abhina_Prakash: Criticizing present day vaccination policy shouldn’t mean presenting a rosy picture of past failures. Pulse polio progr…
# Long: None, Lati: None
# RT @jacoblorinc: "'You could hear the bombs in the background, it was absolutely terrifying,' she said. Still, her aunt greeted her with a…
# Long: None, Lati: None
# RT @Poonam89625917: Thank you sir, for supporting us.
# Hope we get an attempt this year and get a last chance to prove ourselves.
# Just one l…
# Long: None, Lati: None
# "None of these people should be in this situation. A secure home, an affordable home is a basic human right. At a b… https://t.co/tzV1AI1rI0
# Long: None, Lati: None
# RT @jimmy58871193: Please help us
# #UPSCExtraAttempt2021
# #Age_Relaxation https://t.co/op2xWiF14x
# Long: None, Lati: None
# @Peterman43 The nightmare of having medicines delivered by PO years ago is still very much alive in my mind. They e… https://t.co/wHI8l5Sk0P
# Long: None, Lati: None
# Actually, he got two historic peace treaties signed between the UAE, Bahrain and Israel. Something Libs like you sa… https://t.co/IS2xRP6wNE
# Long: None, Lati: None
# What a disaster
# Long: None, Lati: None
# RT @ndtv: "24 teams pre-deployed and 29 teams on standby for Kerala, Karnataka, Tamil Nadu, Gujarat and Maharashtra ahead of #CycloneTaukta…
# Long: None, Lati: None
# If the petition is right to you then please sign the petition and share it
# https://t.co/okiGRJEDSw
# #ModiMustResign… https://t.co/drHAGG71W5
# Long: None, Lati: None
# This is an interesting watch for aeroplane/engineering fans.
#
# We often quickly hear about automation going wrong a… https://t.co/QcZzqMStcg
# Long: None, Lati: None
# RT @cdemacu: Official signage was mounted today at the Arnos Vale Logistics Hub in support of the La Soufrière Volcano in St. Vincent and t…
# Long: None, Lati: None
# RT @Kenny_Wallace: Coincidence or not?. TRUMP is gone. And America is in DRAMA.. No one will get a Job. Border Crisis - Gasoline is a disas…
# Long: None, Lati: None
# RT @RoryHearne: "None of these people should be in this situation. A secure home, an affordable home is a basic human right. At a basic lev…
# Long: None, Lati: None
# surprising bangtan did so well in holding themselves from speaking english?😂 i felt like all the other people befor… https://t.co/Jio70I2Wcv
# Long: None, Lati: None
# ‘Impending disaster.’ Worsening algae bloom on Lake Okeechobee threatens coasts again https://t.co/blNcFXaJy6
# Long: None, Lati: None
# Home Minister is spearheading the fight against those who are serving the mankind . Be it pappu yadav or be it Srin… https://t.co/uqRk8bSfxn
# Long: None, Lati: None
# RT @SwatantrVichaar: Thank you for the Support @SinghShaktiBJP.
# Pls help us and raise our voice more strongly at higher levels of the Govt.…
# Long: None, Lati: None
# RT @rebel4SSR: Radhe is a Disaster! Few positive reviews are all done due to heat &amp; quick payments from SKF.
#
# Few loyals of Bhoi too have t…
# Long: None, Lati: None
# @bcmakes They should have the balls to say "yes, btc is an environmental disaster, but I like it anyway"
#
# TBF I've… https://t.co/SZkdQC8tQ4
# Long: None, Lati: None
# RT @crzyfkinworld: So, the CDC just announced that if you’re fully vaccinated you don’t need to wear a mask indoors, or outside. Idk, maybe…
# Long: None, Lati: None
# @BinanceUS - it's been MORE than 2 weeks since I submitted my verification and yet no word. This is a disaster.… https://t.co/M8dJQPjPan
# Long: None, Lati: None
# @GillPlusFive When we feel this way about ourselves it’s so hard to get out of it. We have to remind ourselves to b… https://t.co/ucQMGPTQlx
# Long: None, Lati: None
# RT @Ravidabra07: #महा_मूर्ख_दिवस
# I promise you Mr.@narendramodi , there will be a day where the people of this Nation will not be judged b…
# Long: None, Lati: None
# @joedementia8 @CBSNews Not sure why you think reuniting children with their families is a disaster. Sounds like a you problem.
# Long: None, Lati: None
# @Stephen4_2 McStay lost the ball needlessly in midfield and I don't think another Scotland outfielder touched it un… https://t.co/WSjOkQMgGG
# Long: None, Lati: None
# On 2 July I will be attempting to walk the UK's three highest mountains in under 24 hours to raise money for… https://t.co/kll0ueNyll
# Long: None, Lati: None
# RT @sandeep_PT: Anyone who helps other citizens, must be investigated.
#
# Anyone who predicts a disaster in advance, must be a conspirator.…
# Long: None, Lati: None
# #Plasticpollution in our oceans is an immense environmental disaster. @TheOceanCleanup’s new tool shows people the… https://t.co/XAmqm9178r
# Long: None, Lati: None
# RT @Kashyapmanish15: Home Minister is spearheading the fight against those who are serving the mankind . Be it pappu yadav or be it Sriniva…
# Long: None, Lati: None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ff56b86508dd> in <module>
#       1 myStreamListener = MyStreamListener()
#       2 myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
# ----> 3 myStream.filter(languages=["en"], track = settings.TRACK_WORDS)
#       4 # Close the MySQL connection as it finished
#       5 # However, this won't be reached as the stream listener won't stop automatically
#
# ~\Envs\python39env\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\Envs\python39env\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\Envs\python39env\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\Envs\python39env\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\Envs\python39env\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\Envs\python39env\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517             else:
#     518                 cache_content = False
# --> 519                 data = self._fp.read(amt) if not fp_closed else b""
#     520                 if (
#     521                     amt != 0 and not data
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in read(self, amt)
#     453             # Amount is given, implement using readinto
#     454             b = bytearray(amt)
# --> 455             n = self.readinto(b)
#     456             return memoryview(b)[:n].tobytes()
#     457         else:
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in readinto(self, b)
#     487
#     488         if self.chunked:
# --> 489             return self._readinto_chunked(b)
#     490
#     491         if self.length is not None:
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in _readinto_chunked(self, b)
#     582         try:
#     583             while True:
# --> 584                 chunk_left = self._get_chunk_left()
#     585                 if chunk_left is None:
#     586                     return total_bytes
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in _get_chunk_left(self)
#     550                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     551             try:
# --> 552                 chunk_left = self._read_next_chunk_size()
#     553             except ValueError:
#     554                 raise IncompleteRead(b'')
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in _read_next_chunk_size(self)
#     510     def _read_next_chunk_size(self):
#     511         # Read the next chunk size from the file
# --> 512         line = self.fp.readline(_MAXLINE + 1)
#     513         if len(line) > _MAXLINE:
#     514             raise LineTooLong("chunk size")
#
# ~\AppData\Local\Programs\Python\Python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\AppData\Local\Programs\Python\Python39\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\AppData\Local\Programs\Python\Python39\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
